# %% [markdown]
# <a href="https://colab.research.google.com/github/Munnayoung/Munnayoung/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.
print("환영합니다.")

print("파이썬의 세계에 오신 것을 환영합니다.")

print("파이썬은 강력합니다.")
# Out:
# 환영합니다.
# 파이썬의 세계에 오신 것을 환영합니다.
# 파이썬은 강력합니다.
