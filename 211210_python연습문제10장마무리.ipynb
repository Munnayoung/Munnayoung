# %% [markdown]
# <a href="https://colab.research.google.com/github/Munnayoung/Munnayoung/blob/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C-3%EC%9E%A5%EC%9D%B4%ED%9B%84%EB%B6%80%ED%84%B0%EB%9E%91-%EB%8F%84%EC%A0%84%EB%AC%B8%EC%A0%9C%EC%8B%9C%EB%A6%AC%EC%A6%88/211210_python%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C10%EC%9E%A5%EB%A7%88%EB%AC%B4%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5
from tkinter import* #tkinter 모듈에 있는 모든 함수를 포함시키라는 의미
fields='이름','직업','국적'

def fetch(entries): 
  for entry in entries:
    field = entry[0]
    text = entry[1].get()
    print('%s: "%s"' %(field,text))

def makeform(root,fields):
  entries = []
  for field in fields:
    row = Frame(root)
    lab = Label(row,width=15,text=field)
    ent = Entry(row)
    row.pack(side=TOP,fill=X)
    lab.pack(side=LEFT)
    ent.pack(side=RIGHT,expand=YES,fill=X)
    entries.append((field,ent))
  return entries

root = TK() #최상위 root를 생성한다
ents = makeform(root,fields)
root.bind('<Return>',(lambda event, e =ents: fetch(e)))
b1 = Button(root,text='보여주기', #버튼위젯을 생성한다
     command = (lambda e =ents: fetch(e)))
bl.pack(side=LEFT,padx=5,pady=5)
b2 = Button(root,text='종료하기',command=root,quit) #버튼위젯을 생성한다
b2.pack(side=LEFT,padx=5,pady=5)
root.mainloop() #여러가지 이벤트 함수를 처리하는 함수이다

# %%
6
from tkinter import* #tkinter  모듈에 있는 모든 함수를 포함시키라는 의미

window = TK() #최상위 윈도우 생성하기
label1 = Label(window,text="로그인 하세요!!!",font=("Helvetica",20)) #label위젯 생성하기
label1.pack()
label2=Label(window,text="아이디") #label위젯 생성하기
label2.pack()
entry1 = Entry(window)
entry1.pack()
label2 = Label(window,text="패스워드")#라벨위젯 생성하기
label2.pack()
entry2 = Entry(window)
entry.pack()
button1 = Button(window,text="로그인") #버튼위젯 생성하기
button1.pack() #버튼에 대하여 pack( )메소드가 호출된다
window.mainloop() #여러가지 이벤트를 처리 하는 함수

# %%
7
from random import * #랜덤 모듈을 불러낸디
from tkinter import * #tkinter 모듈에 있는 모든 함수를 포함시킨다

#선택 하는 부분
def user_choice_rock():
  user_choice= "rock" #주먹을 고른다
  turn(user_choice)
  user_image.configyre(image=rock_image)
def user_choice_paper(): 
  user_choice = "paper" #보를 고른다
  turn(user_choice)
  user_image.configure(image=paper_image)
def user_choice_scissors():
    user_choice ="scissors" #가위를 고른다
    turn(user_choice)
    user_image.configure(image=scissors_image)

#게임부분
def turn(user_choice): #사용자가 선택한다
  oppo = ['rock','paper','scissors']
  oppo_choice=oppo[randint(0,2)]
  if(oppo_choice=='rock'): #선택이 주먹이랑 같다면
    oppo_image.configure(image=rock_image)
    if (user_choice=='paper'): #선택이 보랑 같다면
      turn_result.configure(text="사용자 승!",fg="green")
      compare.configure(text=">>>>>")
    elif(user_choice=='scissors'): #선택이 가위랑 같다면
      turn_result.configure(text="컴퓨터 승!",fg="red")
      compare.congigure("text="<<<<<")
    else: #그렇지 않다면
      turn_result.configure(text="무승부",fg="gray")
      compare.configure(text="=====")

  elif(oppo_choice=='paper'): #선택이 보랑 같다면
    oppo_image.configure(image=paper_image)
    if(user_choice=='scissors'): #선택이 가위랑 같다면
      turn_result.configure(text="사용자 승!",fg="green")
      compare.configure(text=">>>>>")
    elif(user_choice=='rock'): #선택이 보랑 같다면
      turn_result.configure(text="컴퓨터 승!",fg="red")
      compare.configure(text="<<<<<")
    else: #그렇지 않다면
      turn_result.configure(text="무승부",fg="gray")
      compare.configure(text="=====")

    elif(oppo_choice=='scissors'): #선택이 가위랑 같다면
      oppo_image.configure(image=scissors_image)
      if(user_choice=='rock'): #선택이 주먹이랑 같다면
        turn_result.configure(text="시용자 승!",fg="green")
        compare.configure(text=">>>>>")
      elif(user_choice=='paper'): #선택이 보랑 같다면
        turn_result.configure(text="컴퓨터 승!",fg="red")
        compare.configure("text="<<<<<"")
        else: #그렇지 않다면
          turn_result.configure(text="무승부,fg="gray")
          compare.configure(text="=====")

#메인 프로그램
main_window = TK() #최상위 윈도우를 생성한다
rock_button = Button(main_window,width=20,text="바위",justify=CENTER,command=user_choice_rock, activebackground='balck',activeground='white')
paper_button = Button(main_window,width=20,text="보",justify=CENTER,commabd=user_choice_paper,activebackground='balck',activeforeground='white')
scissors_button = Button(main_window,width=20,text="가위",justify=CENTER,command=user_choice_scissors,activebackground='black',activeground='white')
rock_image=PhotoImage(file="d:/rock.gif")
paper_image=PhotoImage(file"d:/paper.gif")
scissors_image=PhotoImage(file"d:/scissors.gif")
user_image = Label(text="사용자",image=rock_image)
user_image.image=rock_image
compare = Label(main_window,justify=CENTER,font=("Helvetica,30"))
oppo_image = Label(text="컴퓨터",image=paper_image)
oppo_image.image=paper_image
turn_result=Label(main_window,width=20,justifyCENTER,font=("Helvetica",20))

#그리드 생성
rock_button.grid(row=5,column=1)
paper_button.grid(row=5,column2)
scissors_button.grid(row=5,column=3)
user_image.grid(row=3,column=1)
compare.grid(row=3,column=2)
oppo_image.grid(row=3,column=3)
turn_result.grid(row-4,column=2)

#GUI화면 루프 처리
main_window.mainloop()
